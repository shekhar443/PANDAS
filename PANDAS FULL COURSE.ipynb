# %% [markdown]
# # <B>PANDAS INSTALLATION

# %%
## pip install pandas
## import pandas as pd
## pd. __version__
## conda list

# %%
""" 
    1.high perfomence data anlysis
    2.working with large dataset
    3.support r load files with different format
    4.more flexible
    5.represents in tabular way like rows and columns
    6.working on missing data
    7.indexing ---slising=---subsetting on large data
    8.we can merge and join two different datasets
    9.reshape datasets
"""
# Out:
# ' \n1.high perfomence data anlysis\n2.working with large dataset\n3.support r load files with different format\n4.more flexible\n5.represents in tabular way like rows and columns\n6working on missing data\n7.indexing ---slising=---subsetting on large data\n8.we can merge and join two different datasets\n9.reshape datasets\n'

# %% [markdown]
# #  3 TYPES OF STRUCTURES

# %%
"""1.SERIES---1D-----LIST
   2.DATAFRAME---2D-----LIST/DIC/SERIES/ANOTHER DF
   3.PANNEL---3D
"""
# Out:
# '1.SERIES---1D\n   2.DATAFRAME---2D\n   3.PANNEL---3D\n'

# %%
"""
    pd.Series(data,index)
    pd.DataFrame(data)
    pd.Panel(data,major axis,minor axis,dtype)
"""
# Out:
# '\n    pd.Series(data,index)\n    pd.DataFrame(data)\n    pd.Panel(data,major axis,minor axis,dtype)\n'

# %% [markdown]
# # creating series

# %%
import pandas as pd
"""creating series
1.emplty series
2.series using list
3.series using arrays
4.series using dict
"""

# %%
l=[10,20,30,40,50,60,70]
pd.Series(l)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# 5    60
# 6    70
# dtype: int64

# %%
pd.Series(l,index=['A','B','C','D','E','F','G'])
# Out:
# A    10
# B    20
# C    30
# D    40
# E    50
# F    60
# G    70
# dtype: int64

# %%
dict={'name':['shekhar','chandu','kowshik'],'percentage':[90,50,80]}
pd.DataFrame(dict)
# Out:
#       name  percentage
# 0  shekhar          90
# 1   chandu          50
# 2  kowshik          80

# %% [markdown]
# # <b> SERIES

# %%
"""
empty series
series using arrays
series using lists
series using Dictionary
"""
# Out:
# '\nempty series\nseries using arrays\nseries using lists\nseries using Dictionary\n'

# %%
s=pd.Series()
s
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_2164\521516865.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s=pd.Series()
# Series([], dtype: float64)

# %%
l=[5,6,7,8,9,75,6,2,6,5,5,5,7]
l
import numpy as np

# %%
a=np.array([56,85,79,45,63,65])
a
# Out:
# array([56, 85, 79, 45, 63, 65])

# %%
b={'a':1,'b':2,'c':60,'d':50,'e':41,'f':52}
b
# Out:
# {'a': 1, 'b': 2, 'c': 60, 'd': 50, 'e': 41, 'f': 52}

# %%
s1=pd.Series(l)
#s1=pd.Series(l,index=[])
s2=pd.Series(a)
s3=pd.Series(b)

# %%
s1
# Out:
# 0      5
# 1      6
# 2      7
# 3      8
# 4      9
# 5     75
# 6      6
# 7      2
# 8      6
# 9      5
# 10     5
# 11     5
# 12     7
# dtype: int64

# %%
s2
# Out:
# 0    56
# 1    85
# 2    79
# 3    45
# 4    63
# 5    65
# dtype: int32

# %%
s3
# Out:
# a     1
# b     2
# c    60
# d    50
# e    41
# f    52
# dtype: int64

# %% [markdown]
# # DataFrame
# * load the data from excel file
# * load the data from csv file
# * creating df using dict
# * creating a df using list of tuples

# %%
import pandas as pd
import numpy as np
a=pd.read_csv("shekhar.csv")
b=pd.read_excel("shekhar1.xlsx")

# %%
df=pd.DataFrame(a)
df2=pd.DataFrame(b)

# %%
df1
# Out:
#    level   salary
# 0      1    45000
# 1      2    50000
# 2      3    60000
# 3      4    80000
# 4      5   110000
# 5      6   150000
# 6      7   200000
# 7      8   300000
# 8      9   500000
# 9     10  1000000

# %%
df
# Out:
#   level \tsalary
# 0       1\t45000
# 1       2\t50000
# 2       3\t60000
# 3       4\t80000
# 4      5\t110000
# 5      6\t150000
# 6      7\t200000
# 7      8\t300000
# 8      9\t500000
# 9    10\t1000000

# %%
d={'name':['hai','bye','hhh'],
    'per':[56,56,54],
        'branch':['hg','hgg','hgf']}

# %%
d
# Out:
# {'name': ['hai', 'bye', 'hhh'],
#  'per': [56, 56, 54],
#  'branch': ['hg', 'hgg', 'hgf']}

# %%
df3=pd.DataFrame(d)

# %%
df3
# Out:
#   name  per branch
# 0  hai   56     hg
# 1  bye   56    hgg
# 2  hhh   54    hgf

# %% [markdown]
# # attributes in series
# * Series.index
# * Series.array
# * Series.values
# * Series.name
# * Series.shape
# * Series.ndim
# * Series..size
# * Series.nbytes
# * Series.memory_usage()
# * Series.empty

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
df1.values
# Out:
# array([[      1,   45000],
#        [      2,   50000],
#        [      3,   60000],
#        [      4,   80000],
#        [      5,  110000],
#        [      6,  150000],
#        [      7,  200000],
#        [      8,  300000],
#        [      9,  500000],
#        [     10, 1000000]], dtype=int64)

# %%
df1.shape
# Out:
# (10, 2)

# %%
df1.size
# Out:
# 20

# %%
df1.values
# Out:
# array([[      1,   45000],
#        [      2,   50000],
#        [      3,   60000],
#        [      4,   80000],
#        [      5,  110000],
#        [      6,  150000],
#        [      7,  200000],
#        [      8,  300000],
#        [      9,  500000],
#        [     10, 1000000]], dtype=int64)

# %%
df1.ndim
# Out:
# 2

# %%
df1.memory_usage()
# Out:
# Index     128
# level      80
# salary     80
# dtype: int64

# %%
l=[5,6,7,8,9,75,6,2,6,5,5,5,7]
l
# Out:
# [5, 6, 7, 8, 9, 75, 6, 2, 6, 5, 5, 5, 7]

# %%
df=pd.DataFrame(l)

# %%
df
# Out:
#      0
# 0    5
# 1    6
# 2    7
# 3    8
# 4    9
# 5   75
# 6    6
# 7    2
# 8    6
# 9    5
# 10   5
# 11   5
# 12   7

# %%
df3
# Out:
#   name  per branch
# 0  hai   56     hg
# 1  bye   56    hgg
# 2  hhh   54    hgf

# %%
df1
# Out:
#    level   salary
# 0      1    45000
# 1      2    50000
# 2      3    60000
# 3      4    80000
# 4      5   110000
# 5      6   150000
# 6      7   200000
# 7      8   300000
# 8      9   500000
# 9     10  1000000

# %%
df.index
# Out:
# RangeIndex(start=0, stop=13, step=1)

# %% [markdown]
# # mathametical operations
# * ADD
# * SUBSTRACT
# * MULTPLY
# * DIVISION
# * MODULO
# * POWER
# * LESSTHAN
# * GTATERTHAN
# * EQUALSTO
# * consider 2 sreires s1 and s2 and perform operations

# %%
import pandas as pd
import numpy as np
s1=pd.Series([10,20,30,40,50])
s2=pd.Series([40,50,60,70,80])

# %%
s1
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
s1,s2
# Out:
# (0    10
#  1    20
#  2    30
#  3    40
#  4    50
#  dtype: int64,
#  0    40
#  1    50
#  2    60
#  3    70
#  4    80
#  dtype: int64)

# %%
s1.add(s2)
# Out:
# 0     50
# 1     70
# 2     90
# 3    110
# 4    130
# dtype: int64

# %%
s2.subtract(s1)
# Out:
# 0    30
# 1    30
# 2    30
# 3    30
# 4    30
# dtype: int64

# %%
s1.multiply(s2)
# Out:
# 0     400
# 1    1000
# 2    1800
# 3    2800
# 4    4000
# dtype: int64

# %%
s2.divide(s1)
# Out:
# 0    4.00
# 1    2.50
# 2    2.00
# 3    1.75
# 4    1.60
# dtype: float64

# %%
s1.mod(s2)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
s1.pow(s2)
# Out:
# 0   -5047021154770878464
# 1                      0
# 2    1152921504606846976
# 3                      0
# 4                      0
# dtype: int64

# %%
s1.le(s2)
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# dtype: bool

# %%
s2.le(s1)
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
s1.gt(s2)
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
s2.gt(s1)
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# dtype: bool

# %%
s2.eq(s1)
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
s1.eq(s2)
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
s1**s2
# Out:
# 0   -5047021154770878464
# 1                      0
# 2    1152921504606846976
# 3                      0
# 4                      0
# dtype: int64

# %% [markdown]
# # ACCESSING / SLICINNG
# * head()
# * tail()
# * describe()
#     * count
#     * min
#     * max
#     * std
#     * avg
#     * 75%
#     * 50%
#     * 25%
# * shape
# * (start: stop: step:)
#     * (0:len:1) bydefault
# * df[['column_name']]
# * df[['column_name1','column_name2']]
# * df[['column_name1','column-name2']][start:stop:step]
# * for index,row in df.iterrows():
#                 * print(index,row)
# * df.loc[1]
# df.loc[df['column-name']=='value']

# %%
a
# Out:
#   level \tsalary
# 0       1\t45000
# 1       2\t50000
# 2       3\t60000
# 3       4\t80000
# 4      5\t110000
# 5      6\t150000
# 6      7\t200000
# 7      8\t300000
# 8      9\t500000
# 9    10\t1000000

# %%
b
# Out:
#    level   salary
# 0      1    45000
# 1      2    50000
# 2      3    60000
# 3      4    80000
# 4      5   110000
# 5      6   150000
# 6      7   200000
# 7      8   300000
# 8      9   500000
# 9     10  1000000

# %%
b.size
# Out:
# 20

# %%
b.shape
# Out:
# (10, 2)

# %%
b.head(5)
# Out:
#    level  salary
# 0      1   45000
# 1      2   50000
# 2      3   60000
# 3      4   80000
# 4      5  110000

# %%
b.tail(5)
# Out:
#    level   salary
# 5      6   150000
# 6      7   200000
# 7      8   300000
# 8      9   500000
# 9     10  1000000

# %%
b.describe()
# Out:
#           level          salary
# count  10.00000       10.000000
# mean    5.50000   249500.000000
# std     3.02765   299373.883668
# min     1.00000    45000.000000
# 25%     3.25000    65000.000000
# 50%     5.50000   130000.000000
# 75%     7.75000   275000.000000
# max    10.00000  1000000.000000

# %%
df2.describe()
# Out:
#           level          salary
# count  10.00000       10.000000
# mean    5.50000   249500.000000
# std     3.02765   299373.883668
# min     1.00000    45000.000000
# 25%     3.25000    65000.000000
# 50%     5.50000   130000.000000
# 75%     7.75000   275000.000000
# max    10.00000  1000000.000000

# %%
df2.loc[5]
# Out:
# level          6
# salary    150000
# Name: 5, dtype: int64

# %%
df2.loc[1:8:2]
# Out:
#    level   salary
# 9     10  1000000
# 8      9   500000
# 7      8   300000
# 6      7   200000
# 5      6   150000
# 4      5   110000
# 3      4    80000
# 2      3    60000
# 1      2    50000
# 0      1    45000

# %%
df2.loc[5::]
# Out:
#    level   salary
# 5      6   150000
# 6      7   200000
# 7      8   300000
# 8      9   500000
# 9     10  1000000

# %%
df2.loc[df2['salary']==300000]
df2.loc[df2['level']==4]
# Out:
#    level  salary
# 3      4   80000

# %%
df2[::]
# Out:
#    level   salary
# 0      1    45000
# 1      2    50000
# 2      3    60000
# 3      4    80000
# 4      5   110000
# 5      6   150000
# 6      7   200000
# 7      8   300000
# 8      9   500000
# 9     10  1000000

# %% [markdown]
# # sorted values

# %%
df2.sort_values(['salary'],ascending=1)
df2.sort_values(['salary'],ascending=0)
# Out:
#    level   salary
# 9     10  1000000
# 8      9   500000
# 7      8   300000
# 6      7   200000
# 5      6   150000
# 4      5   110000
# 3      4    80000
# 2      3    60000
# 1      2    50000
# 0      1    45000

# %% [markdown]
# # manipulations

# %%
df2['total']=0

# %%
df2['total']=df2['level']+df2['salary']

# %%
df2
# Out:
#    level   salary    total
# 0      1    45000    45001
# 1      2    50000    50002
# 2      3    60000    60003
# 3      4    80000    80004
# 4      5   110000   110005
# 5      6   150000   150006
# 6      7   200000   200007
# 7      8   300000   300008
# 8      9   500000   500009
# 9     10  1000000  1000010

# %%
df2.drop(columns='level')
# Out:
#     salary    total
# 0    45000    45001
# 1    50000    50002
# 2    60000    60003
# 3    80000    80004
# 4   110000   110005
# 5   150000   150006
# 6   200000   200007
# 7   300000   300008
# 8   500000   500009
# 9  1000000  1000010

# %%
import pandas as pd

# %%
dataset=pd.read_csv("D:\student-por.csv")

# %%
dataset
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %%
df=pd.DataFrame(dataset)

# %%
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %%
df.size
# Out:
# 21417

# %%
df.shape
# Out:
# (649, 33)

# %%
df.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000
# mean    16.744222    2.514638    2.306626    1.568567    1.930663    0.221880
# std      1.218138    1.134552    1.099931    0.748660    0.829510    0.593235
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    1.000000    1.000000    1.000000    0.000000
# 50%     17.000000    2.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000
# mean     3.930663    3.180277    3.184900    1.502311    2.280431    3.536210
# ...

# %%
df[['age','goout','G1','G2','G3']]
# Out:
#      age  goout  G1  G2  G3
# 0     18      4   0  11  11
# 1     17      3   9  11  11
# 2     15      2  12  13  12
# 3     15      2  14  14  14
# 4     16      2  11  13  13
# ..   ...    ...  ..  ..  ..
# 644   19      2  10  11  10
# 645   18      4  15  15  16
# 646   18      1  11  12   9
# 647   17      5  10  10  10
# 648   18      1  10  11  11
#
# [649 rows x 5 columns]

# %%
df['sum_gs']=df['G1']+df['G2']+df['G3']

# %%
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %%
df.to_csv("E:\haiii.csv",index=False)

# %%
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %% [markdown]
# # difference between loc and iloc

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("Inc_Exp_Data.csv")

# %%
df
# Out:
#     Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# 0              5000              8000                  3             2000
# 1              6000              7000                  2             3000
# 2             10000              4500                  2                0
# 3             10000              2000                  1                0
# 4             12500             12000                  2             3000
# 5             14000              8000                  2                0
# 6             15000             16000                  3            35000
# 7             18000             20000                  5             8000
# 8             19000              9000                  2                0
# 9             20000              9000                  4                0
# 10            20000             18000                  4             8000
# 11            22000             25000                  6            12000
# ...

# %%
df.columns
# Out:
# Index(['Mthly_HH_Income', 'Mthly_HH_Expense', 'No_of_Fly_Members',
#        'Emi_or_Rent_Amt', 'Annual_HH_Income', 'Highest_Qualified_Member',
#        'No_of_Earning_Members'],
#       dtype='object')

# %%
df.loc[12,'Emi_or_Rent_Amt']
df[5:10]
# Out:
#    Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# 5            14000              8000                  2                0
# 6            15000             16000                  3            35000
# 7            18000             20000                  5             8000
# 8            19000              9000                  2                0
# 9            20000              9000                  4                0
#
#    Annual_HH_Income Highest_Qualified_Member  No_of_Earning_Members
# 5            196560                 Graduate                      1
# 6            167400            Post-Graduate                      1
# 7            216000                 Graduate                      1
# 8            218880           Under-Graduate                      1
# 9            220800           Under-Graduate                      2

# %%
df.loc[14,['Mthly_HH_Expense','Annual_HH_Income']]#label based
# Out:
# Mthly_HH_Expense     10000
# Annual_HH_Income    244800
# Name: 14, dtype: object

# %%
df.iloc[5:10:1]#index based
# Out:
#    Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# 5            14000              8000                  2                0
# 6            15000             16000                  3            35000
# 7            18000             20000                  5             8000
# 8            19000              9000                  2                0
# 9            20000              9000                  4                0
#
#    Annual_HH_Income Highest_Qualified_Member  No_of_Earning_Members
# 5            196560                 Graduate                      1
# 6            167400            Post-Graduate                      1
# 7            216000                 Graduate                      1
# 8            218880           Under-Graduate                      1
# 9            220800           Under-Graduate                      2

# %%
df.loc[5:10:1]
# Out:
#     Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# 5             14000              8000                  2                0
# 6             15000             16000                  3            35000
# 7             18000             20000                  5             8000
# 8             19000              9000                  2                0
# 9             20000              9000                  4                0
# 10            20000             18000                  4             8000
#
#     Annual_HH_Income Highest_Qualified_Member  No_of_Earning_Members
# 5             196560                 Graduate                      1
# 6             167400            Post-Graduate                      1
# 7             216000                 Graduate                      1
# 8             218880           Under-Graduate                      1
# 9             220800           Under-Graduate                      2
# ...

# %%
df.iloc[3:10,2:5]
# Out:
#    No_of_Fly_Members  Emi_or_Rent_Amt  Annual_HH_Income
# 3                  1                0             97200
# 4                  2             3000            147000
# 5                  2                0            196560
# 6                  3            35000            167400
# 7                  5             8000            216000
# 8                  2                0            218880
# 9                  4                0            220800

# %%
df[df['Emi_or_Rent_Amt']==0]
# Out:
#     Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# 2             10000              4500                  2                0
# 3             10000              2000                  1                0
# 5             14000              8000                  2                0
# 8             19000              9000                  2                0
# 9             20000              9000                  4                0
# 12            23400              5000                  3                0
# 13            24000             10500                  6                0
# 14            24000             10000                  4                0
# 15            25000             12300                  3                0
# 17            25000             10000                  6                0
# 19            30000             13000                  4                0
# 21            32000             15000                  4                0
# ...

# %%
df.isnull().sum()
# Out:
# Mthly_HH_Income             0
# Mthly_HH_Expense            0
# No_of_Fly_Members           0
# Emi_or_Rent_Amt             0
# Annual_HH_Income            0
# Highest_Qualified_Member    0
# No_of_Earning_Members       0
# dtype: int64

# %%
df.isnull().any
df.isnull().values
df.dropna()
# Out:
#     Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# 0              5000              8000                  3             2000
# 1              6000              7000                  2             3000
# 2             10000              4500                  2                0
# 3             10000              2000                  1                0
# 4             12500             12000                  2             3000
# 5             14000              8000                  2                0
# 6             15000             16000                  3            35000
# 7             18000             20000                  5             8000
# 8             19000              9000                  2                0
# 9             20000              9000                  4                0
# 10            20000             18000                  4             8000
# 11            22000             25000                  6            12000
# ...

# %%
df.dropna(inplace=True)

# %%
df['Emi_or_Rent_Amt'].dropna()
# Out:
# 0      2000
# 1      3000
# 2         0
# 3         0
# 4      3000
# 5         0
# 6     35000
# 7      8000
# 8         0
# 9         0
# 10     8000
# 11    12000
# 12        0
# 13        0
# 14        0
# 15        0
# 16     3500
# 17        0
# 18     2000
# 19        0
# 20     5000
# 21        0
# 22        0
# 23     4000
# 24        0
# 25        0
# 26        0
# 27        0
# 28        0
# 29        0
# 30        0
# 31     3500
# 32     1000
# 33     2500
# 34     3500
# 35        0
# 36        0
# 37        0
# 38    12000
# 39        0
# 40    10000
# 41     5000
# 42        0
# 43        0
# 44        0
# 45        0
# 46        0
# 47        0
# 48    20000
# 49    10000
# Name: Emi_or_Rent_Amt, dtype: int64

# %%
df.fillna("haiiiiiiii")
# Out:
#     Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# 0              5000              8000                  3             2000
# 1              6000              7000                  2             3000
# 2             10000              4500                  2                0
# 3             10000              2000                  1                0
# 4             12500             12000                  2             3000
# 5             14000              8000                  2                0
# 6             15000             16000                  3            35000
# 7             18000             20000                  5             8000
# 8             19000              9000                  2                0
# 9             20000              9000                  4                0
# 10            20000             18000                  4             8000
# 11            22000             25000                  6            12000
# ...

# %%
df['Emi_or_Rent_Amt'].fillna(30)
# Out:
# 0      2000
# 1      3000
# 2         0
# 3         0
# 4      3000
# 5         0
# 6     35000
# 7      8000
# 8         0
# 9         0
# 10     8000
# 11    12000
# 12        0
# 13        0
# 14        0
# 15        0
# 16     3500
# 17        0
# 18     2000
# 19        0
# 20     5000
# 21        0
# 22        0
# 23     4000
# 24        0
# 25        0
# 26        0
# 27        0
# 28        0
# 29        0
# 30        0
# 31     3500
# 32     1000
# 33     2500
# 34     3500
# 35        0
# 36        0
# 37        0
# 38    12000
# 39        0
# 40    10000
# 41     5000
# 42        0
# 43        0
# 44        0
# 45        0
# 46        0
# 47        0
# 48    20000
# 49    10000
# Name: Emi_or_Rent_Amt, dtype: int64

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# dtype: bool

# %%
df.drop_duplicates()
# Out:
#     Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# 0              5000              8000                  3            False
# 1              6000              7000                  2            False
# 2             10000              4500                  2             True
# 3             10000              2000                  1             True
# 4             12500             12000                  2            False
# 5             14000              8000                  2             True
# 6             15000             16000                  3            False
# 7             18000             20000                  5            False
# 8             19000              9000                  2             True
# 9             20000              9000                  4             True
# 10            20000             18000                  4            False
# 11            22000             25000                  6            False
# ...

# %%
df.loc[df['No_of_Fly_Members']<3]
# Out:
#     Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# 1              6000              7000                  2            False
# 2             10000              4500                  2             True
# 3             10000              2000                  1             True
# 4             12500             12000                  2            False
# 5             14000              8000                  2             True
# 8             19000              9000                  2             True
# 18            29000              6600                  2            False
# 32            45000             10000                  2            False
# 42            70000              9000                  2             True
#
#     Annual_HH_Income Highest_Qualified_Member  No_of_Earning_Members
# 1              79920               Illiterate                      1
# 2             112800           Under-Graduate                      1
# ...

# %%
df.loc[(df['No_of_Fly_Members']<3) & (df['Mthly_HH_Expense']<10000)]
# Out:
#     Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# 1              6000              7000                  2            False
# 2             10000              4500                  2             True
# 3             10000              2000                  1             True
# 5             14000              8000                  2             True
# 8             19000              9000                  2             True
# 18            29000              6600                  2            False
# 42            70000              9000                  2             True
#
#     Annual_HH_Income Highest_Qualified_Member  No_of_Earning_Members
# 1              79920               Illiterate                      1
# 2             112800           Under-Graduate                      1
# 3              97200               Illiterate                      1
# 5             196560                 Graduate                      1
# ...

# %%
df.loc[(df['No_of_Fly_Members']<3) | (df['Mthly_HH_Expense']<10000)]
# Out:
#     Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# 0              5000              8000                  3            False
# 1              6000              7000                  2            False
# 2             10000              4500                  2             True
# 3             10000              2000                  1             True
# 4             12500             12000                  2            False
# 5             14000              8000                  2             True
# 8             19000              9000                  2             True
# 9             20000              9000                  4             True
# 12            23400              5000                  3             True
# 18            29000              6600                  2            False
# 26            39000              8000                  4             True
# 32            45000             10000                  2            False
# ...

# %%
df.loc[df['Highest_Qualified_Member'].str.contains("Gra")]
# Out:
#     Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# 0              5000              8000                  3            False
# 2             10000              4500                  2             True
# 4             12500             12000                  2            False
# 5             14000              8000                  2             True
# 6             15000             16000                  3            False
# 7             18000             20000                  5            False
# 8             19000              9000                  2             True
# 9             20000              9000                  4             True
# 10            20000             18000                  4            False
# 13            24000             10500                  6             True
# 14            24000             10000                  4             True
# 15            25000             12300                  3             True
# ...

# %%
df.loc[df['Highest_Qualified_Member'].str.contains("era")]
# Out:
#     Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# 1              6000              7000                  2            False
# 3             10000              2000                  1             True
# 11            22000             25000                  6            False
# 12            23400              5000                  3             True
# 41            65000             20000                  4            False
#
#     Annual_HH_Income Highest_Qualified_Member  No_of_Earning_Members
# 1              79920               Illiterate                      1
# 3              97200               Illiterate                      1
# 11            279840               Illiterate                      1
# 12            292032               Illiterate                      1
# 41            647400               Illiterate                      2

# %%
df.loc[df['Highest_Qualified_Member'].str.contains("Und")]
# Out:
#     Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# 0              5000              8000                  3            False
# 2             10000              4500                  2             True
# 8             19000              9000                  2             True
# 9             20000              9000                  4             True
# 10            20000             18000                  4            False
# 17            25000             10000                  6             True
# 20            30500             25000                  5            False
# 26            39000              8000                  4             True
# 27            40000             10000                  4             True
# 44            85000             25000                  5             True
#
#     Annual_HH_Income Highest_Qualified_Member  No_of_Earning_Members
# 0              64200           Under-Graduate                      1
# ...

# %%
df.loc[~df['Highest_Qualified_Member'].str.contains("Gra")]
# Out:
#     Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# 1              6000              7000                  2            False
# 3             10000              2000                  1             True
# 11            22000             25000                  6            False
# 12            23400              5000                  3             True
# 21            32000             15000                  4             True
# 22            34000             19000                  6             True
# 23            34000             25000                  3            False
# 25            35000             25000                  4             True
# 31            45000             40000                  6            False
# 35            47000             15000                  7             True
# 36            50000             20000                  4             True
# 37            50500             20000                  3             True
# ...

# %%
df.loc[df['Highest_Qualified_Member'].str.startswith("Gra")]
# Out:
#     Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# 4             12500             12000                  2            False
# 5             14000              8000                  2             True
# 7             18000             20000                  5            False
# 13            24000             10500                  6             True
# 14            24000             10000                  4             True
# 15            25000             12300                  3             True
# 16            25000             20000                  3            False
# 18            29000              6600                  2            False
# 19            30000             13000                  4             True
# 24            35000             12000                  3             True
# 28            42000             15000                  4             True
# 29            43000             12000                  4             True
# ...

# %%
df.loc[df['Highest_Qualified_Member'].str.endswith("uate")]
# Out:
#     Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# 0              5000              8000                  3            False
# 2             10000              4500                  2             True
# 4             12500             12000                  2            False
# 5             14000              8000                  2             True
# 6             15000             16000                  3            False
# 7             18000             20000                  5            False
# 8             19000              9000                  2             True
# 9             20000              9000                  4             True
# 10            20000             18000                  4            False
# 13            24000             10500                  6             True
# 14            24000             10000                  4             True
# 15            25000             12300                  3             True
# ...
