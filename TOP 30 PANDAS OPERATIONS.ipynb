# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_excel('E:\\tableau simplilearn\\Sample - Superstore.xls')

# %%
dataset.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
dataset.to_csv("dataset.csv",sep="|",index=False)

# %%
# !cat dataset.csv
# Out:
# 'cat' is not recognized as an internal or external command,
# operable program or batch file.

# %%
data=[[1,2,'np.nan'],['np.nan',5,6],[5,"love",'9']]

# %%
df=pd.DataFrame(data,columns=['col1','col2','col3'])

# %%
df
# Out:
#      col1  col2    col3
# 0       1     2  np.nan
# 1  np.nan     5       6
# 2       5  love       9

# %%
data={"col1":['df','np.nan',5],
     "col2":[5,'hgjf','hj'],
     "col3":['cv','np.nan',6]}

# %%
df2=pd.DataFrame(data=data)

# %%
df2
# Out:
#      col1  col2    col3
# 0      df     5      cv
# 1  np.nan  hgjf  np.nan
# 2       5    hj       6

# %%
print("shape: ",df.shape)
# Out:
# shape:  (3, 3)

# %%
dataset.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
dataset.dtypes
# Out:
# Row ID                    int64
# Order ID                 object
# Order Date       datetime64[ns]
# Ship Date        datetime64[ns]
# Ship Mode                object
# Customer ID              object
# Customer Name            object
# Segment                  object
# Country                  object
# City                     object
# State                    object
# Postal Code               int64
# Region                   object
# Product ID               object
# Category                 object
# Sub-Category             object
# Product Name             object
# Sales                   float64
# Quantity                  int64
# Discount                float64
# Profit                  float64
# dtype: object

# %%
dataset.Quantity=dataset.Quantity.astype(np.int8)

# %%
dataset.dtypes
# Out:
# Row ID                    int64
# Order ID                 object
# Order Date       datetime64[ns]
# Ship Date        datetime64[ns]
# Ship Mode                object
# Customer ID              object
# Customer Name            object
# Segment                  object
# Country                  object
# City                     object
# State                    object
# Postal Code               int64
# Region                   object
# Product ID               object
# Category                 object
# Sub-Category             object
# Product Name             object
# Sales                   float64
# Quantity                   int8
# Discount                float64
# Profit                  float64
# dtype: object

# %%
dataset.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   datetime64[ns]
#  3   Ship Date      9994 non-null   datetime64[ns]
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
dataset.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
df2.isnull().sum()
# Out:
# col1    0
# col2    0
# col3    0
# dtype: int64

# %%
df.fillna(0,inplace=True)

# %%
pd.merge(df,df2,on='col3')
# Out:
#    col1_x col2_x    col3  col1_y col2_y
# 0       1      2  np.nan  np.nan   hgjf
# 1  np.nan      5       6       5     hj

# %%
dataset.sort_values('Profit',ascending=False)
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 6826    6827  CA-2016-118689 2016-10-02 2016-10-09  Standard Class
# 8153    8154  CA-2017-140151 2017-03-23 2017-03-25     First Class
# 4190    4191  CA-2017-166709 2017-11-17 2017-11-22  Standard Class
# 9039    9040  CA-2016-117121 2016-12-17 2016-12-21  Standard Class
# 4098    4099  CA-2014-116904 2014-09-23 2014-09-28  Standard Class
# ...      ...             ...        ...        ...             ...
# 4991    4992  US-2017-122714 2017-12-07 2017-12-13  Standard Class
# 3011    3012  CA-2017-134845 2017-04-17 2017-04-23  Standard Class
# 9774    9775  CA-2014-169019 2014-07-26 2014-07-30  Standard Class
# 683      684  US-2017-168116 2017-11-04 2017-11-04        Same Day
# 7772    7773  CA-2016-108196 2016-11-25 2016-12-02  Standard Class
#
#      Customer ID   Customer Name      Segment        Country         City  \
# 6826    TC-20980    Tamara Chand    Corporate  United States    Lafayette
# ...

# %%
df3=pd.DataFrame([[1,8,2,'A'],[9,6,8,'B'],[2,6,3,'c'],[5,6,4,'A']],columns=['col1','col2','col3','col4'], index=['A',"B","C","D"])

# %%
df3
# Out:
#    col1  col2  col3 col4
# A     1     8     2    A
# B     9     6     8    B
# C     2     6     3    c
# D     5     6     4    A

# %%
df3.sort_values('col3')
# Out:
#    col1  col2  col3 col4
# A     1     8     2    A
# C     2     6     3    c
# D     5     6     4    A
# B     9     6     8    B

# %%
df3.groupby('col4').agg({'col1':sum,'col2':max})
# Out:
#       col1  col2
# col4
# A        6     8
# B        9     6
# c        2     6

# %%
df.rename(columns={'col1':"col-A",'col2':"col-B"},inplace=True)

# %%
df
# Out:
#     col-A col-B    col3
# 0       1     2  np.nan
# 1  np.nan     5       6
# 2       5  love       9

# %%
df.drop(columns=['col3'],axis=1)
# Out:
#     col-A col-B
# 0       1     2
# 1  np.nan     5
# 2       5  love

# %%
df["new"]=df3['col1']+df3["col2"]+df3["col3"]

# %%
df
# Out:
#     col-A col-B    col3  new
# 0       1     2  np.nan  NaN
# 1  np.nan     5       6  NaN
# 2       5  love       9  NaN

# %%
df3["new"]=df3['col1']+df3["col2"]+df3["col3"]

# %%
df3
# Out:
#    col1  col2  col3 col4  new
# A     1     8     2    A   11
# B     9     6     8    B   23
# C     2     6     3    c   11
# D     5     6     4    A   15

# %%
df3[df3['col3']>5]
# Out:
#    col1  col2  col3 col4  new
# B     9     6     8    B   23

# %%
df3['col1']
# Out:
# A    1
# B    9
# C    2
# D    5
# Name: col1, dtype: int64

# %%
df3
# Out:
#    col1  col2  col3 col4  new
# A     1     8     2    A   11
# B     9     6     8    B   23
# C     2     6     3    c   11
# D     5     6     4    A   15

# %%
df3.loc['A']
# Out:
# col1     1
# col2     8
# col3     2
# col4     A
# new     11
# Name: A, dtype: object

# %%
df3.loc[['A','B']]
# Out:
#    col1  col2  col3 col4  new
# A     1     8     2    A   11
# B     9     6     8    B   23

# %%
df3.loc[['A','B'],['col3','col4']]
# Out:
#    col3 col4
# A     2    A
# B     8    B

# %%
df3.iloc[2]
# Out:
# col1     2
# col2     6
# col3     3
# col4     c
# new     11
# Name: C, dtype: object

# %%
df3.iloc[:2,:2]
# Out:
#    col1  col2
# A     1     8
# B     9     6

# %%
df3['col4'].unique()
# Out:
# array(['A', 'B', 'c'], dtype=object)

# %%
df3['col4'].nunique()
# Out:
# 3

# %%
def square(num):
    return num**2

# %%
df3['col5']=df3['col1'].apply(square)

# %%
square(df3.col1)
# Out:
# A     1
# B    81
# C     4
# D    25
# Name: col1, dtype: int64

# %%
df3
# Out:
#    col1  col2  col3 col4  new  col5
# A     1     8     2    A   11     1
# B     9     6     8    B   23    81
# C     2     6     3    c   11     4
# D     5     6     4    A   15    25

# %%
df3.duplicated(keep=False)
# Out:
# A    False
# B    False
# C    False
# D    False
# dtype: bool

# %%
df3.drop_duplicates()
# Out:
#    col1  col2  col3 col4  new  col5
# A     1     8     2    A   11     1
# B     9     6     8    B   23    81
# C     2     6     3    c   11     4
# D     5     6     4    A   15    25

# %%
df3['col2'].value_counts()
# Out:
# 6    3
# 8    1
# Name: col2, dtype: int64

# %%
df3.reset_index()
# Out:
#   index  col1  col2  col3 col4  new  col5
# 0     A     1     8     2    A   11     1
# 1     B     9     6     8    B   23    81
# 2     C     2     6     3    c   11     4
# 3     D     5     6     4    A   15    25

# %%
df3.set_index(df3['col2'])
# Out:
#       col1  col2  col3 col4  new  col5
# col2
# 8        1     8     2    A   11     1
# 6        9     6     8    B   23    81
# 6        2     6     3    c   11     4
# 6        5     6     4    A   15    25

# %%
df3.set_index(df3['col4'])
# Out:
#       col1  col2  col3 col4  new  col5
# col4
# A        1     8     2    A   11     1
# B        9     6     8    B   23    81
# c        2     6     3    c   11     4
# A        5     6     4    A   15    25

# %%
df3.reset_index()
# Out:
#   index  col1  col2  col3 col4  new  col5
# 0     A     1     8     2    A   11     1
# 1     B     9     6     8    B   23    81
# 2     C     2     6     3    c   11     4
# 3     D     5     6     4    A   15    25

# %%
df3.reset_index(drop=True)
# Out:
#    col1  col2  col3 col4  new  col5
# 0     1     8     2    A   11     1
# 1     9     6     8    B   23    81
# 2     2     6     3    c   11     4
# 3     5     6     4    A   15    25

# %%
pd.crosstab(df3.col1,df3.col3)
# Out:
# col3  2  3  4  8
# col1
# 1     1  0  0  0
# 2     0  1  0  0
# 5     0  0  1  0
# 9     0  0  0  1

# %%
df3=...

# %%
df3
# Out:
# Ellipsis
